# %%
from utils import *

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create dataframe

# %%
date = pd.date_range('2010-01-01', '2012-12-31')

# %%
symbols = ['SPY', 'XOM', 'GOOG', 'GLD']

# %%
df = get_data(symbols, date)

# %%
plot_data(df)

# %% [markdown]
# # Lesson

# %% [markdown]
# ## Compute Global Statistics

# %%
print(df.mean())
# Out:
# SPY     112.043312
# XOM      73.296221
# GOOG    568.941941
# GLD     142.603279
# dtype: float64

# %%
print(df.std())
# Out:
# SPY     10.745846
# XOM     10.168104
# GOOG    54.068129
# GLD     20.562938
# dtype: float64

# %%
# Compute Bollinger Bands
# 1. Compute rolling mean
rm_SPY = get_rolling_mean(df['SPY'], window=20)

# 2. Compute rolling standard deviation
rstd_SPY = get_rolling_std(df['SPY'], window=20)

# 3. Compute upper and lower bands
upper_band, lower_band = get_bollinger_bands(rm_SPY, rstd_SPY)
    
# Plot raw SPY values, rolling mean and Bollinger Bands
ax = df['SPY'].plot(title="Bollinger Bands", label='SPY')
rm_SPY.plot(label='Rolling mean', ax=ax)
upper_band.plot(label='upper band', ax=ax)
lower_band.plot(label='lower band', ax=ax)

# Add axis labels and legend
ax.set_xlabel("Date")
ax.set_ylabel("Price")
ax.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Daily return

# %%
a = compute_daily_return(df)

# %%
a.head()
# Out:
#                  SPY       XOM      GOOG       GLD
# 2012-09-12  0.000000  0.000000  0.000000  0.000000
# 2012-09-11 -0.003324  0.000782  0.001896 -0.000119
# 2012-09-10 -0.002780 -0.001562  0.012395 -0.003633
# 2012-09-07  0.005714  0.004917  0.007677  0.006874
# 2012-09-06 -0.003880 -0.010343 -0.009559 -0.021076

# %%
b = compute_cumulative_return(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-1914df1e6ab7> in <module>()
# ----> 1 b = compute_cumulative_return(df)
#
# /Users/hoangnguyen/Documents/Github/machine-learning-for-trading/utils.py in compute_cumulative_return(df)
#      72
#      73 def compute_cumulative_return(df):
# ---> 74     return (df/df[0]) - 1
#      75
#      76 def test_run():
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 0

# %%
b.head()
