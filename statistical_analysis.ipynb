# %%
from read_plot import *

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create dataframe

# %%
date = pd.date_range('2010-01-01', '2012-12-31')

# %%
symbols = ['SPY', 'XOM', 'GOOG', 'GLD']

# %%
df = get_data(symbols, date)

# %%
plot_data(df)

# %% [markdown]
# # Lesson

# %% [markdown]
# ## Compute Global Statistics

# %%
print(df.mean())
# Out:
# SPY     112.043312
# XOM      73.296221
# GOOG    568.941941
# GLD     142.603279
# dtype: float64

# %%
print(df.std())
# Out:
# SPY     10.745846
# XOM     10.168104
# GOOG    54.068129
# GLD     20.562938
# dtype: float64
